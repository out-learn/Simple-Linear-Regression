# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('delivery_time.csv')
df.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
df.shape
# Out:
# (21, 2)

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
df.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
df['log_d'] = np.log(df['Delivery Time'])

# %%
# model building 

x = df.drop('Delivery Time', axis=1)
y = df['Delivery Time']

# %%
model_d1 = smf.ols("log_d~x", data=df).fit()

# %%
model_d1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  log_d   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.432e+30
# Date:                Wed, 03 Apr 2024   Prob (F-statistic):          1.30e-265
# Time:                        15:39:47   Log-Likelihood:                 706.34
# No. Observations:                  21   AIC:                            -1407.
# Df Residuals:                      18   BIC:                            -1404.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4.441e-16   1.83e-15     -0.243      0.811   -4.29e-15     3.4e-15
# ...

# %%
df['log_s'] = np.log(df['Sorting Time'])

# %%
model_d2 = smf.ols("y~log_s", data=df).fit()

# %%
model_d2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.695
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     43.39
# Date:                Wed, 03 Apr 2024   Prob (F-statistic):           2.64e-06
# Time:                        15:41:35   Log-Likelihood:                -50.912
# No. Observations:                  21   AIC:                             105.8
# Df Residuals:                      19   BIC:                             107.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1597      2.455      0.472      0.642      -3.978       6.297
# ...

# %%
model_d3 = smf.ols("log_d~log_s", data=df).fit()

# %%
model_d3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  log_d   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     64.39
# Date:                Wed, 03 Apr 2024   Prob (F-statistic):           1.60e-07
# Time:                        15:42:55   Log-Likelihood:                 10.291
# No. Observations:                  21   AIC:                            -16.58
# Df Residuals:                      19   BIC:                            -14.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7420      0.133     13.086      0.000       1.463       2.021
# ...

# %%
model_d4 = smf.ols("y~x", data=df).fit()

# %%
model_d4.params
# Out:
# Intercept   -26.778966
# x[0]         -0.010935
# x[1]         15.726474
# dtype: float64

# %%
model_d4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     236.6
# Date:                Wed, 03 Apr 2024   Prob (F-statistic):           1.19e-13
# Time:                        15:44:05   Log-Likelihood:                -28.678
# No. Observations:                  21   AIC:                             63.36
# Df Residuals:                      18   BIC:                             66.49
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -26.7790      2.902     -9.228      0.000     -32.876     -20.682
# ...

# %%
y_predict = pd.DataFrame(model_d4.predict(x))

# %%
y_predict.head()
# Out:
#            0
# 0  20.991292
# 1  14.108428
# 2  20.069913
# 3  23.102205
# 4  26.067379

# %%
lr = LinearRegression()
